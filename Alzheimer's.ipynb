# %% [markdown]
# # Module_1: *Alzheimer's Intro*
#
# ## Team Members:
# *Senada Mujanovic, Cecilia Andreae*
#
# ## Project Title:
# *Researching Alzheimer's*

# %% [markdown]
# ## Project Goal:
# This project seeks to... *if there is correlation between death age and phosphorylated Tau tangles and amyloid beta plaques in Alzheimer's.*

# %% [markdown]
# ## Disease Background:
# *Fill in information about 11 bullets:*
#
# * Prevalence & incidence
# * * 7.4 million cases in the US (2.16% of population)
#   * 200k under 65
#   * 65+ 7.2 mil (1 in 9 or 11% of 65+)
#   * Incidence (new cases/year):
#   * * Based on the Chicago Health and Aging Project (CHAP) data:
# * * * * Ages 65–74: ~0.4% per year (4 out of 1,000)
#       * Ages 75–84: ~3.2% per year (32 out of 1,000)
#       * Ages 85 and older: ~7.6% per year (76 out of 1,000)
#     * Data found via chatgpt "Preavalence and Incidence of Alzheimer's) verified using PubMED and Alzheimer's Association
# * Risk factors (genetic, lifestyle)
# * * Age (strongest risk factor, partly genetic/biological)
# * * * Risk rises sharply after age 65.
#     * By age 85, up to 1 in 3 people may have Alzheimer’s.
# * * Family history
#   * Having a first-degree relative (parent, sibling) with Alzheimer’s increases risk, especially if multiple family members are affected.
#   * Genes
#   * * APOE gene:
#     * APOE ε4 allele is the most well-established genetic risk factor.
#     * One copy increases risk 2–3×; two copies increase risk up to 10–15×.
#     * lowers the average age of onset.
#   * Early-onset (familial) Alzheimer’s genes: rare mutations (<1% of cases).
#   * * APP (amyloid precursor protein)
#     * PSEN1 (presenilin 1)
#     * PSEN2 (presenilin 2)
#     * Mutations in these genes virtually guarantee Alzheimer’s, usually before age 60.
#   * Other genetic factors under study: TREM2, CLU, PICALM, CR1, and others that affect inflammation, amyloid processing, or lipid metabolism.
# 🧬 Lifestyle & Environmental Risk Factors
# * * Cardiovascular health (“What’s good for the heart is good for the brain”)
# * * High blood pressure (midlife hypertension strongly linked)
# * * Diabetes
# * * High cholesterol
# * * Obesity (especially midlife obesity)
# * * Smoking
# * * Sedentary lifestyle
# * * Unhealthy diets (high in saturated fats, processed foods, sugar) raise risk.
# * * Cognitive & social engagement
# * *  * Low education levels and limited mental stimulation may increase risk.
#      * Lifelong learning, bilingualism, mentally challenging activities, and strong social connections appear protective.
# * * Sleep: Poor sleep quality, chronic insomnia, or sleep apnea raise risk. Sleep is critical for clearing beta-amyloid from the brain.
# * * Head trauma
# * * * Moderate-to-severe traumatic brain injury (TBI), especially with loss of consciousness, increases risk.
#   * * Repeated head injuries (e.g., in contact sports) further elevate risk.
# * * Depression and chronic stress (Associated with higher Alzheimer’s risk, though it’s unclear if they are causes, early symptoms, or both)
# * * Alcohol use
# * * * Heavy, long-term alcohol use is linked to cognitive decline.
# * * * Moderate use (particularly red wine in Mediterranean diet context) may have neutral or mild protective effects.
# * * Environmental exposures: Air pollution and heavy metals
# * Continuum of care providers
#   * Primary care providers
#     * first point of contact
#     * monitor general health, coordinate referrals
#   * Neurologists
#     * Diagnose Alzheimer's
#     * order imaging, cognitive tests, and manage disease specific medications
#   * Psychiatrists
#     * Manage depression, anxiety, agitation, psychosis.
#     * Prescribe medications for behavioral and psychological symptoms of dementia (BPSD)
#   * Geriatricians
#     * Specialists in elderly care, focus on balancing multiple conditions common in older adults.
#   * Nurse Practitioners (NPs) & Physician Assistants (PAs)
#     * Provide ongoing monitoring, patient education, and medication management in collaboration with physicians
#   * Radiologists - analyze imaging
#   * Nurses - medication management monitor health, patient and caregiver education,
#   * Physical Therapists - maintain mobility balance reduce fall risks
#   * Speech Language Pathologists - help with communication language and swallowing issues
#   * Counselors/Mental Health Workers - monitor mental health and provide support
# Alzheimer’s Association (alz.org)
# National Institute on Aging (nia.nih.gov)
#
# * Biological mechanisms (anatomy, organ physiology, cell & molecular physiology)
#   * Brain regions
#     * Cerebral cortex, Hippocampus, Basal forebrain, Later spread (frontal cortex, occipital lobes), brain shrinkage (atrophy)
#   * Amyloid beta plaque
#      * create extracellular plaque due to abnormal cleaving
#      * disrupt synaptic signaling, promote inflammation, and impair cell survival
#   * Buildup of Tau causing Tau tangles
#     * tTau: total Tau
#     * pTau: phosphorylated Tau
#     * tau becomes hyperphosphorylated → detaches, aggregates into tangles
#     * normally stabilizes microtubules but then causes collapse
#   * Inflammation
#     * Microglia and atrocytes which detect plaque/tangles become chronically activated
#     * They release cytokines, ROS, and complement proteins which cause further injury
#   * Axon between neuron dendrites (aaccept signals) and terminals (send signals through synapses)
#     * mylon sheath adds to movement
#     * tau tangle and amyloid beta plaque disrupt this
# https://www.alz.org/alzheimers-dementia/what-is-alzheimers?utm_source=chatgpt.com
# * Clinical Trials/next-gen therapies
#     * Lifestyle:
#       * Protective diets: Mediterranean and MIND diets (rich in vegetables, fruits, fish, whole grains, olive oil, nuts)
#       * Cardiovascular health
#       * Excersize
#     * Anti amyloid beta plaque
#        * Lecanemab (Leqembi) — anti-Aβ protofibril antibody. Shown to slow cognitive decline in CLARITY-AD; now in real-world follow-ups and longer-term extension studies. Regulatory approvals and access vary by country. Safety monitoring centers on ARIA (amyloid-related imaging abnormalities)
#        * Donanemab (Kisunla, Lilly) — approved (US 2023; label updates since) after TRAILBLAZER-ALZ-2 showed reduced clinical decline in early AD and measurable plaque clearance; ARIA remains an important adverse effect to manage
#        * Aducanumab — earlier accelerated approval; clinical benefit debated and use is limited by safety/cost/efficacy issues
#     * Anti tau therapies
#       * Monoclonal antibodies against tau (e.g., semorinemab, gosuranemab, tilavonemab, zagotenemab): multiple trials have reported mixed results; some show target engagement but limited clinical benefit so far — several programs continue in refined designs
#       * Small molecules / aggregation inhibitors / ASOs (antisense oligonucleotides) designed to reduce tau expression or aggregation are in early-phase studies
#     * Neuroinflammation and innate immunity modulators
#       * Modulate microglia/astrocyte responses to reduce chronic damaging inflammation and improve clearance of pathology
#       * TREM2-targeted agents (e.g., AL002) — aim to modulate microglial activation to improve plaque clearance and neuroprotection; mixed Phase 2 readouts have led to iterative program changes
#     * Genetic and gene based therapies
#       * Correct or compensate for genetic contributors (e.g., APOE4), or deliver protective genes
#       * AAV-based gene delivery (early trials in AD/FTD populations), ASOs to knock down pathogenic transcripts, and exploratory CRISPR approaches are entering preclinical/early clinical phases. A recent CTAD taskforce overview highlights planned/early gene therapy trials and the field’s challenges (delivery, safety, patient selection)
#     * small molecules metabolic and repurposed drugs
#       * GLP-1 receptor agonists (e.g., semaglutide) —
#       * several randomized trials are testing whether metabolic/insulin-sensitizing effects slow cognitive decline;
#       * results expected from major trials in 2025–2026
#       * Synaptic enhancers, mitochondrial protectors, kinase inhibitors, PROTACs —
#       * many in Phase 1/2. The 2024–25 literature highlights new modalities
#       * (PROTACs, allosteric modulators) entering development.
#     * vaccines / active immunizations
#       * Elicit an immune response to clear Aβ or tau
#       * Several vaccine candidates are in early human trials (peptide vaccines, DNA vaccines, and novel platforms)
#       * Safety and adequate immunogenicity while avoiding harmful inflammation are main challenges
#     * Biomarker and trial enabling advances
#       * Blood biomarkers (p-tau217, p-tau181, NfL) now enable faster,
#       * cheaper screening and recruitment to trials; trials are increasingly biomarker-driven.
# https://pmc.ncbi.nlm.nih.gov/articles/PMC12061918/?utm_source=chatgpt.com
# https://investors.alector.com/news-releases/news-release-details/alector-announces-results-al002-invoke-2-phase-2-trial?utm_source=chatgpt.com
# https://www.sciencedirect.com/science/article/pii/S2274580725002122?utm_source=chatgpt.com
# https://www.alzheimers.org.uk/research/our-research/dementia-research-news/researching-new-drugs-alzheimers-disease?utm_source=chatgpt.com
# https://pmc.ncbi.nlm.nih.gov/articles/PMC12131090/?utm_source=chatgpt.com
# https://www.nature.com/articles/s41392-024-01911-3?utm_source=chatgpt.com
#
# * Economic burden
# - Found in ChatGPT and linked site ( linked site has really good gragh of Total annual economic cost)
# - Total Annual Economic Cost - $781 billion (2025 est.)
# - Direct Healthcare Costs - $305 billion (2020) -> projected > $1 trillion (by2050)
# - Informal/Indirect Costs - $832 billion (2024)
# - Formal Medical care - $28,078 per patient
# - Inrofmal Care (replacment cost) - 36, 667
# - Per Patient (formal + informal) - $64-65k anually
# https://schaeffer.usc.edu/research/dementia-alzheimers-cost-model-2025/
#
# * Societal determinants
# Education:
# - Lower education is strongly associated with increased Alzheimer's risk
# - People with less than a high school edcuation have about 2x higher risk of developing dementia
# - Estimated impact - 19% of Alzheimers cases in the US can be attributed to low education alone
# https://www.cdc.gov/alzheimers-dementia/php/sdoh/index.html
#
# Income and Socioeconomic Status:
# - Lower-income individuals are:
# - Less likely to access preventive care
# - More exposed to risk factors (like poor nutrition, unmanaged diabetes)
# - Low-income adults are at 60–70% greater risk for cognitive decline compared to wealthier peers.
# - Black and Latino populations, who face systemic economic barriers, are disproportionately affected.
#
# Access to Healthcare:
# - Rural Americans are 50% more likely to be undiagnosed or diagnosed later.
# - People without regular primary care are more likely to miss early intervention.
# - Minority groups are less likely to receive cognitive screening or referrals to neurologists.
#
# Neighborhood and Envieonment:
# Living in areas with:
# - Poor air quality
# - Limited green space
# - Unsafe walking environments
# - Fewer social resources
# …is associated with faster cognitive decline.
# - Residents in disadvantaged neighborhoods face nearly 2x the risk of dementia progression.
#
# * Symptoms
# - Memory Loss
# - Difficulty with problem solving and planning
# - Confusion with time or Place
# - Dificulty Completing Familair Tasks
# - Language problems
# - Misplacing things
# - Withdrawl from work or social activities
# - Changes in mood or perosnality
# - Problems with visual or spatial relationships
#
# Alzheimers Progression Stages
# Early - mild memory loss, small personality changes
# Middle - Noticeable confusion, increased supervision needed
# Late - Loss of speech, mobility, and complete dependence
# https://www.alz.org/alzheimers-dementia/10_signs
#
# * Diagnosis
# - Medical History - Identify risk factors, symptom timeline
# - Cognitive testing - Assess mental functions
# - Neurological exam - Rule out stroke, Parkinson's etc.
# - Blood and lab Tests - Exclude other medical conditions
# - Brain Imaging (MRI, PET) - Detect brain changes (atrophy, plaques)
# - Biomaarkers (CSF, blood) - confirm Alzheimer's pathology (advanced)
# - Psychiatric Evalution - Rule out depression or anxiety
#
# First youll probably see a Primary care physician before seeing a specialist/ neurologist before testing and scans from the radiologistsand blood work etc. then getting the diagnosis.
#
# https://www.alz.org/alzheimers-dementia/diagnosis/medical_tests?utm_source=google&utm_medium=paidsearch&utm_campaign=google_strategic_search&gad_source=1&gad_campaignid=22801691028&gbraid=0AAAAAD8nX1oYC_WYgDKCQTCLxaRw19YYn&gclid=Cj0KCQjwoP_FBhDFARIsANPG24P9-R4Em1xpkCwKiD60rHIWtTwo1_htFnZcxc130QCxNkvqzJiF6cIaAu_YEALw_wcB
#
#
# * Standard of care treatments (& reimbursement)
# - Symptomatic drugs (e.g., donepezil, memantine) - Medicare Part D - Covered if on formulary; standard cost-sharing applies
# - Lecanemab (Leqembi) & Donanemab (Kisunla) - Medicare Part B + registry requirement - Must have early-stage disease + amyloid confirmation; patient data entered into registry; 20% coinsurance
# - Aducanumab (Aduhelm) - Medicare Part B (Trial-only) - Only for participants in CMS‑approved RCTs
# - Diagnostic PET scans - Medicare Part B - Covered when medically justified
# - Therapies, assessments, equipment - Medicare Part B - Covered if medically necessary
# - Long-term custodial care, respite care - Not covered by Medicare - Must use Medicaid/private pay/hospice/other programs
# https://healthpolicy.duke.edu/sites/default/files/2020-03/duke_alzheimerissuebrief-2020.pdf
#
# * Disease progression & prognosis
# - Preclinical (10-20 years before symptoms)
# Pathology (amyloid plaques & tau tangles) begins silently.
# No noticeable cognitive symptoms.
# Detected only via biomarkers (CSF, PET scans) in research or specialized settings.
# - Mild cognitive Impairment (MCI) due to AD
# Memory issues beyond normal aging but not severe enough to interfere significantly with daily life.
# Often the first noticeable symptoms to others.
# Roughly 10–15% progress to dementia each year.
# - Alzheimers Dementia
# a. Mild Stage:
# Short-term memory loss (e.g., forgetting recent conversations)
# Difficulty with complex tasks (finances, planning)
# Personality changes (apathy, depression)
#
# b. Moderate Stage:
# Disorientation, confusion
# Speech and language problems
# Trouble recognizing family or friends
# Behavioral issues (aggression, wandering)
#
# c. Severe Stage:
# Complete dependence for care
# Loss of speech and mobility
# Incontinence
# High risk for infections, especially pneumonia
#
# - Prognosis
# Life Expectancy After Diagnosis:
# Average: 8–10 years
# Range: 3 to 20 years, depending on:
# Age at diagnosis
# Overall health
# Sex (women live slightly longer)
# Coexisting conditions (cardiovascular disease, diabetes)
# Survival Rates by Age
# Diagnosed at 65–75: median survival ~ 7–10 years
# Diagnosed at over 85: median survival ~ 3–4 years
#
# - Factors influencing Faster Progression
# Early onset (<65 years)
# Male sex
# Lower education level
# Poor cardiovascular health
# Presence of neuropsychiatric symptoms (e.g., hallucinations)
#
# - Cause of Death
# Common causes:
# Pneumonia (aspiration due to dysphagia)
# Infections
# Malnutrition
# Falls and fractures
# Complications of immobility
# - Incurrable at the moment but progression can be slowed
#
# https://www.hopkinsmedicine.org/health/conditions-and-diseases/alzheimers-disease/stages-of-alzheimer-disease

# %% [markdown]
# ## Data-Set:
# UpdatedMetaData.csv
# - has qualitative patient info such as study they were involved in, sex, race, highest level of education, years of education, age at death
# - medical info such as genetic risk factors, head injuries, clinical diagnosi, age of onset of symptomns, age of dementia diagnosis, and age of death
# - ex-vivo information from donation of brain
#
# UpdatedlLuminex.csv
# - measurements of amyloid beta plaque and tau tangles in AD
#
# overall:
# -33 male donors and 51 female donors, with an average age at time of death of 88 years
# - used quantitative neuropathology to place donors along a disease
# pseudoprogression score
#
# - QUESTION:
# - is there is a certain threshold range of phosphorylated Tau tangles and amyloid beta plaques where the patient suffering from Alzeihmer's disease will die?

# %%
import csv

with open('UpdatedMetaData.csv', newline="") as file:
    reader = csv.reader(file)
    headers = next(reader)  # Skip the header row
    print("Column Headers:", headers)
# Out:
# Column Headers: ['Donor ID', 'Primary Study Name', 'Secondary Study Name', 'Age at Death', 'Sex', 'Race (choice=White)', 'Race (choice=Black/ African American)', 'Race (choice=Asian)', 'Race (choice=American Indian/ Alaska Native)', 'Race (choice=Native Hawaiian or Pacific Islander)', 'Race (choice=Unknown or unreported)', 'Race (choice=Other)', 'specify other race', 'Hispanic/Latino', 'Highest level of education', 'Years of education', 'APOE Genotype', 'Cognitive Status', 'Age of onset cognitive symptoms', 'Age of Dementia diagnosis', 'Known head injury', 'Have they had neuroimaging', 'Consensus Clinical Dx (choice=Alzheimers disease)', 'Consensus Clinical Dx (choice=Alzheimers Possible/ Probable)', 'Consensus Clinical Dx (choice=Ataxia)', 'Consensus Clinical Dx (choice=Corticobasal Degeneration)', 'Consensus Clinical Dx (choice=Control)', 'Consensus Clinical Dx (choice=Dementia with Lewy Bodies/ Lewy Body Disease)', 'Consensus Clinical Dx (choice=Frontotemporal lobar degeneration)'
# ...

# %% [markdown]
# ## Data Analyis:
# *(Describe how you analyzed the data. This is where you should intersperse your Python code so that anyone reading this can run your code to perform the analysis that you did, generate your figures, etc.)*

# %% [markdown]
# importing data to analyze and configuring the two datasets together by creating a Patient object that contains each individuals information

# %%
import csv
import warnings
import matplotlib.pyplot as plt

class Patient: 

    all_patients = []

    death_age = []

    education_lvl = {}

    def __init__(self, DonorID, ABeta40: float , ABeta42: float, tTau: float, pTau: float):

        self.DonorID = DonorID
        self.ABeta40 = ABeta40
        self.ABeta42 = ABeta42
        self.tTau = tTau
        self.pTau = pTau
        self.sex = None
        self.death_age = None
        self.ed_lvl = None
        self.cog_stat = None
        self.age_symp_on = None
        self.age_diag = None 
        self.head_inj = None
        self.thal_score = None
        Patient.all_patients.append(self)

    def __repr__(self):
        return f"{self.DonorID} | sex: {self.sex} | ABeta40 {self.ABeta40} | tTau {self.tTau} | pTau {self.pTau} | Death Age {self.death_age} | Thal Score {self.thal_score}"

    def get_id(self):
        return self.DonorID

    def get_ABeta42(self):
        return self.ABeta42
    
    def get_thal(self):
        return self.thal_score
    
    def get_death_age(self):
        return self.death_age
    
    @classmethod
    def combine_data(cls, filename: str):
            with open(filename, encoding="utf8") as f:
                reader = csv.DictReader(f)
                rows_of_patients = list(reader)
                #for line in csv create object
                for row in range(len(rows_of_patients)):
                    if Patient.all_patients[row].DonorID == rows_of_patients[row]["Donor ID"]:
                        if rows_of_patients[row]["Sex"] != "":
                            Patient.all_patients[row].sex = rows_of_patients[row]["Sex"]

                        if rows_of_patients[row]["Age at Death"] != "":
                            Patient.all_patients[row].death_age = int(rows_of_patients[row]["Age at Death"])

                        if rows_of_patients[row]["Highest level of education"] != "":
                            Patient.all_patients[row].ed_lvl = rows_of_patients[row]["Highest level of education"]

                        if rows_of_patients[row]["Cognitive Status"] != "":
                            Patient.all_patients[row].cog_stat = rows_of_patients[row]["Cognitive Status"]

                        if rows_of_patients[row]["Age of onset cognitive symptoms"] != "":
                            Patient.all_patients[row].age_symp_on = int(rows_of_patients[row]["Age of onset cognitive symptoms"])

                        if rows_of_patients[row]["Age of Dementia diagnosis"] != "":
                            Patient.all_patients[row].age_diag = int(rows_of_patients[row]["Age of Dementia diagnosis"])

                        if rows_of_patients[row]["Known head injury"] != "":
                            Patient.all_patients[row].head_inj = rows_of_patients[row]["Known head injury"]

                        if rows_of_patients[row]["Thal"] != "":
                            Patient.all_patients[row].thal_score = int(rows_of_patients[row]["Thal"].split()[1])
            
                    else:
                        warnings.warn("IDs do not match.")
   
    @classmethod
    def instantiate_from_csv(cls, filename: str, other_file: str):
    #open csv and create list of all rows
        with open(filename, encoding="utf8") as f:
            reader = csv.DictReader(f)
            rows_of_patients = list(reader)
            #for line in csv create object
            for row in rows_of_patients:
                Patient(
                    DonorID = row['Donor ID'],
                    ABeta40 = float(row['ABeta40 pg/ug']),
                    ABeta42 = float(row['ABeta42 pg/ug']),
                    tTau = float(row['tTAU pg/ug']),
                    pTau = float(row['pTAU pg/ug'])
                )
            Patient.all_patients.sort(key = Patient.get_id)
            Patient.combine_data(other_file)
    
    #6) MAKE A FILTER TO PULL OUT PATIENTS WITH SPECIIFC ATTRIBUTES

    @classmethod
    def filter(cls, list, ABeta40:float ="any", ABeta42:float ="any", tTau:float= "any", pTau:float ="any", sex:str ="any", death_age:int ="any", ed_lvl:str ="any", cog_stat:str ="any", age_symp_on:int ="any", age_diag:int ="any", head_inj:str ="any", thal_score:int ="any"):
        all_patients = list
        remove_list = []
        attr_list = (
                    ABeta40,
                    ABeta42,
                    tTau,
                    pTau,
                    sex,
                    death_age,
                    ed_lvl,
                    cog_stat,
                    age_symp_on,
                    age_diag,
                    head_inj,
                    thal_score
                    )
        attr_name = (
                    "ABeta40",
                    "ABeta42",
                    "tTau",
                    "pTau",
                    "sex",
                    "death_age",
                    "ed_lvl",
                    "cog_stat",
                    "age_symp_on",
                    "age_diag",
                    "head_inj",
                    "thal_score"
                    )
        for attr in range(len(attr_list)):
            if attr_list[attr] != "any":
                for patient in all_patients:
                    if getattr(patient,attr_name[attr]) != attr_list[attr]:
                        remove_list.append(patient)
                all_patients = [patient for patient in all_patients if patient not in remove_list]
                remove_list.clear()
        
        return all_patients

# %% [markdown]
# instantiate and check data

# %%
patient = Patient.instantiate_from_csv('UpdatedLuminex.csv', 'UpdatedMetaData.csv')

Patient.instantiate_from_csv('UpdatedLuminex.csv', 'UpdatedMetaData.csv')

for patient in Patient.all_patients:
    print(patient)
# Out:
# H19.33.004 | sex: Female | ABeta40 0.019621053 | tTau 1552.414737 | pTau 1.901052632 | Death Age 80 | Thal Score 0
# H19.33.004 | sex: None | ABeta40 0.019621053 | tTau 1552.414737 | pTau 1.901052632 | Death Age None | Thal Score None
# H20.33.001 | sex: Male | ABeta40 0.215789474 | tTau 756.0905263 | pTau 2.737894737 | Death Age 82 | Thal Score 2
# H20.33.001 | sex: None | ABeta40 0.215789474 | tTau 756.0905263 | pTau 2.737894737 | Death Age None | Thal Score None
# H20.33.002 | sex: Female | ABeta40 0.000597895 | tTau 313.5252632 | pTau 2.615789474 | Death Age 97 | Thal Score 0
# H20.33.002 | sex: None | ABeta40 0.000597895 | tTau 313.5252632 | pTau 2.615789474 | Death Age None | Thal Score None
# H20.33.004 | sex: Male | ABeta40 60.76631579 | tTau 318.5284211 | pTau 7.412631579 | Death Age 86 | Thal Score 5
# H20.33.004 | sex: None | ABeta40 60.76631579 | tTau 318.5284211 | pTau 7.412631579 | Death Age None | Thal Score None
# ...

# %%
#USE OUR FILTER TO PULL OUT AND COUNT SUB-SETS OF PATIENTS THAT ARE FILTERED

healthy = Patient.filter(Patient.all_patients, cog_stat = "No dementia")
diseased = Patient.filter(Patient.all_patients, cog_stat = "Dementia")

healthy_patients = range(len(Patient.filter(Patient.all_patients, cog_stat = "No dementia")))
healthy_pat = range (len(healthy))
diseased_patients = range(len(Patient.filter(Patient.all_patients, cog_stat = "Dementia")))

print(f'Healthy Patients = {len(healthy_patients)} | Diseased Patients = {len(diseased_patients)}')
print (f'Healthy Patients = {len(healthy)} | Diseased Patients = {len(diseased)}')
# Out:
# Healthy Patients = 42 | Diseased Patients = 42
# Healthy Patients = 42 | Diseased Patients = 42

# %%
#finding and verifying average pTau in healthy patients and creating a set of pTau values

healthypTauTotal = 0
hpTau_set = []
num = len(healthy)
n = 0
for p in healthy:
    healthypTauTotal += p.pTau
    hpTau_set.append(p.pTau)
    n +=1

avgTau = healthypTauTotal / num
print(f'Average tTau in Healthy Patients = {avgTau}')

print(healthypTauTotal)
print(n)
# Out:
# Average tTau in Healthy Patients = 3.7560902256666666
# 157.755789478
# 42

# %%
#finding and verifying average pTau in diseased patients and creating a set of pTau values

diseasepTauTotal = 0
dpTau_set = []
num2 = len(diseased)
n2 = 0
for p in diseased:
    diseasepTauTotal += p.pTau
    dpTau_set.append(p.pTau)
    n2 +=1
avgTau2 = diseasepTauTotal / num2
print(f'Average tTau in Diseased Patients = {avgTau2}')
print(diseasepTauTotal)
# Out:
# Average tTau in Diseased Patients = 4.657543859595235
# 195.6168421029999

# %%
#Use datasets of pTau values in healthy and diseased patients to calculate means, standard deviations, and perform t-test
#and create bar graph with error bars

import numpy as np
import matplotlib.pyplot as plt
from scipy import stats


# Calculate means and standard deviations
hmean, dmean = np.mean(hpTau_set), np.mean(dpTau_set)
stdh, stdd = np.std(hpTau_set, ddof=1), np.std(dpTau_set, ddof=1)


# Perform independent t-test
t_stat, p_val = stats.ttest_ind(hpTau_set, dpTau_set)


# Plot bar graph with error bars
labels = ['Healthy Mean pTau', 'Diseased Mean pTau']
means = [hmean, dmean]
stds = [stdh, stdd]


plt.bar(labels, means, yerr=stds, capsize=8, color=['skyblue', 'lightcoral'], alpha=0.8)
plt.ylabel('Average Value')
plt.title('Comparison of Mean pTau Levels')


# Annotate t-value on plot
plt.text(0.5, max(means) + max(stds), f"t = {t_stat:.2f}, p = {p_val:.3f}",
ha='center', fontsize=10, fontweight='bold')


plt.show()

# %%
# Extract death age and pTau for healthy and diseased patients
healthy_death_age = [p.death_age for p in healthy if p.death_age is not None]
healthy_pTau = [p.pTau for p in healthy if p.death_age is not None]

diseased_death_age = [p.death_age for p in diseased if p.death_age is not None]
diseased_pTau = [p.pTau for p in diseased if p.death_age is not None]

plt.scatter(healthy_death_age, healthy_pTau, color='skyblue', label='Healthy')
plt.scatter(diseased_death_age, diseased_pTau, color='salmon', label='Diseased')

plt.xlabel('Death Age')
plt.ylabel('pTau Amount')
plt.title('Death Age vs pTau Amount')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Linear regression for healthy group
slope_h, intercept_h, r_value_h, p_value_h, std_err_h = stats.linregress(healthy_death_age, healthy_pTau)
line_h = np.array(healthy_death_age) * slope_h + intercept_h

# Linear regression for diseased group
slope_d, intercept_d, r_value_d, p_value_d, std_err_d = stats.linregress(diseased_death_age, diseased_pTau)
line_d = np.array(diseased_death_age) * slope_d + intercept_d

plt.scatter(healthy_death_age, healthy_pTau, color='skyblue', label='Healthy')
plt.scatter(diseased_death_age, diseased_pTau, color='salmon', label='Diseased')

plt.plot(healthy_death_age, line_h, color='blue', linestyle='--', label='Healthy Regression')
plt.plot(diseased_death_age, line_d, color='red', linestyle='--', label='Diseased Regression')

plt.xlabel('Death Age')
plt.ylabel('pTau Amount')
plt.title('Death Age vs pTau Amount with Linear Regression')
plt.legend()
plt.show()

print("R healthy:", r_value_h)       # correlation coefficient
print("R-squared healthy :", r_value_h**2)

print ("R diseased:", r_value_d)       # correlation coefficient
print("R-squared diseased:", r_value_d**2)
# Out:
# R healthy: 0.0851789696354096
# R-squared healthy : 0.00725545686815003
# R diseased: -0.2059455758820472
# R-squared diseased: 0.04241358022538806

# %%
# Extract death age and ABeta42 for healthy and diseased patients and create a scatter plot
healthy_death_age_ABeta42 = [p.death_age for p in healthy if p.death_age is not None]
healthy_ABeta42 = [p.ABeta42 for p in healthy if p.death_age is not None]

diseased_death_age_ABeta42 = [p.death_age for p in diseased if p.death_age is not None]
diseased_ABeta42 = [p.ABeta42 for p in diseased if p.death_age is not None]

plt.scatter(healthy_death_age_ABeta42, healthy_ABeta42, color='skyblue', label='Healthy')
plt.scatter(diseased_death_age_ABeta42, diseased_ABeta42, color='salmon', label='Diseased')

plt.xlabel('Death Age')
plt.ylabel('ABeta42 Amount')
plt.title('Death Age vs ABeta42 Amount')
plt.legend()
plt.show()

# %%
from scipy.stats import linregress

# Linear regression for healthy group (ABeta42)
slope_h_abeta, intercept_h_abeta, r_value_h_abeta, p_value_h_abeta, std_err_h_abeta = linregress(healthy_death_age_ABeta42, healthy_ABeta42)
line_h_abeta = np.array(healthy_death_age_ABeta42) * slope_h_abeta + intercept_h_abeta

# Linear regression for diseased group (ABeta42)
slope_d_abeta, intercept_d_abeta, r_value_d_abeta, p_value_d_abeta, std_err_d_abeta = linregress(diseased_death_age_ABeta42, diseased_ABeta42)
line_d_abeta = np.array(diseased_death_age_ABeta42) * slope_d_abeta + intercept_d_abeta

plt.scatter(healthy_death_age_ABeta42, healthy_ABeta42, color='skyblue', label='Healthy')
plt.scatter(diseased_death_age_ABeta42, diseased_ABeta42, color='salmon', label='Diseased')

plt.plot(healthy_death_age_ABeta42, line_h_abeta, color='blue', linestyle='--', label='Healthy Regression')
plt.plot(diseased_death_age_ABeta42, line_d_abeta, color='red', linestyle='--', label='Diseased Regression')

plt.xlabel('Death Age')
plt.ylabel('ABeta42 Amount')
plt.title('Death Age vs ABeta42 Amount with Linear Regression')
plt.legend()
plt.show()

print("R healthy:", r_value_h_abeta)       # correlation coefficient
print("R-squared healthy :", r_value_h_abeta**2)

print ("R diseased:", r_value_d_abeta)       # correlation coefficient
print("R-squared diseased:", r_value_d_abeta**2)
# Out:
# R healthy: 0.2876641144376347
# R-squared healthy : 0.08275064273518858
# R diseased: -0.22070202200123137
# R-squared diseased: 0.04870938251543202

# %%
import csv

output_file = "PatientDataExport.csv"

with open(output_file, mode="w", newline="", encoding="utf8") as f:
    writer = csv.writer(f)
    #Header
    writer.writerow([
    "DonorID", "Diagnosis", "ABeta40", "ABeta42",
    "tTau", "pTau",
    "Age at Death", "Sex"
    ])
    #Rows
    for patient in Patient.all_patients:
        writer.writerow([
            patient.DonorID,
            patient.cog_stat,
            patient.ABeta40,
            patient.ABeta42,
            patient.tTau,
            patient.pTau,
            patient.death_age,
            patient.sex
        ])

print(f"✅ Patient data exported to {output_file}")
# Out:
# ✅ Patient data exported to PatientDataExport.csv

# %% [markdown]
# ## Verify and validate your analysis:
# We investigated many different values to find correlations in the dataset that would provide clarity to our question that is there is a certain threshold range of phosphorylated Tau tangles and amyloid beta plaques where the patient suffering from Alzeihmer's disease will die?
#
# The first bar graph explores the difference between mean phosphorylated Tau values in healthy and diseased patients. Our error bars overlap and the p value is 0.111 so the null hypothesis that there is no difference between the means is not rejected. (Cite something here)
#
# pTau vs Death Age
# R healthy: 0.0851789696354096
# R-squared healthy : 0.00725545686815003
# R diseased: -0.2059455758820472
# R-squared diseased: 0.04241358022538806
#
# Amyloid Beta vs Death Age
# R healthy: 0.2876641144376347
# R-squared healthy : 0.08275064273518858
# R diseased: -0.22070202200123137
# R-squared diseased: 0.04870938251543202
#
#
# When comparing death age with abeta42 or pTau the R value (correlation coefficient), always rounds to zero showing no correlation/very weak correlation between death age and amount of beta plaque buildup or phosphorylated tau tangles.
#
#
# In addition, the R squared value for both pTau and amyloid beta is even closer to zero, both in healthy and diseased patients showing that very little of the variance in death age can be explained by the amount of these proteins are present in the brain.
#
# Source Analysis:
# Source 1: "Lower CSF Aβ42 (p = 0.010) and higher CSF T-tau (p = 0.005) at the age of 85 were associated with lower survival independently of dementia status at baseline and follow-up." The research paper's findings do align with our lack of finding a correlation between death age and amyloid beta and pTau through the fact that if pTau and amyloid beta levels are found higher despite lack of dementia status, all dead patients regardless of dementia would have the buildup and there wouldn't be a large correlation to find.
#
# Source 2: This study found that there are biomarkers found in AD such as higher levels of pTau and amyloid beta plaques which contradicts our bar graph that showed no significant difference in pTau levels between AD and non AD patients through the use of a t test. Our lack of correlation is likely due to the small sample size. However, source 1 that shows a correlation between pTau and amyloid beta in patients dying over the age of 85 regardless of dementia status can explain some of the lack of significant difference. Perhaps if the patients pTau and amyloid were measured consistently while they were alive better analyis could have been made, although a larger dataset also likely would have allowed us to find a significant difference in the levels.
#
#
# 1. Ribbe M, Kern S, Börjesson Hansson A, Östling S, Zetterberg H, Blennow K, Skoog I. Amyloid β42 and Total Tau Levels in Cerebrospinal Fluid Associate with Survival in an 85-Year-Old Population-Based Cohort Followed until Death. Dement Geriatr Cogn Disord. 2019;47(1-2):114-124. doi: 10.1159/000499066. Epub 2019 Apr 10. PMID: 30970371.
#
# 2. Tariciotti L, Casadei M, Honig LS, Teich AF, McKhann Ii GM, Tosto G, Mayeux R. Clinical Experience with Cerebrospinal Fluid Aβ42, Total and Phosphorylated Tau in the Evaluation of 1,016 Individuals for Suspected Dementia. J Alzheimers Dis. 2018;65(4):1417-1425. doi: 10.3233/JAD-180548. PMID: 30149454; PMCID: PMC6218126.

# %% [markdown]
# ## Conclusions and Ethical Implications:
# *(Think about the answer your analysis generated, draw conclusions related to your overarching question, and discuss the ethical implications of your conclusions.*
#
# Our analysis shows that while there were observable differences in pTau levels between Alzheimer’s patients and control patients, the t-test did not find these differences to be statistically significant. This means we cannot conclude that elevated pTau alone is associated with Alzheimer’s disease. However, the scatter plots and regression analyses highlight a relationship between pTau and Aβ42 within the Alzheimer’s group, reinforcing the idea that these biomarkers may play a role in disease pathology. These findings align with the broader understanding of Alzheimer’s as a protein-accumulation disorder and suggest that pTau and Aβ42 together may still be useful in distinguishing affected patients from controls, even if pTau alone does not provide a definitive marker.
#
# From an ethical standpoint, this research involves sensitive patient data, so maintaining privacy and confidentiality remains essential. Care must also be taken in interpreting and communicating these findings: biomarker differences on their own cannot serve as a clinical diagnosis of Alzheimer’s without additional context. Researchers and clinicians should present results responsibly, avoiding overstated claims that could mislead patient care or cause undue concern. By emphasizing both the potential and the limitations of biomarker-based studies, we support a more ethical and cautious approach to advancing Alzheimer’s research.

# %% [markdown]
# ## Limitations and Future Work:
# *(Think about the answer your analysis generated, draw conclusions related to your overarching question, and discuss the ethical implications of your conclusions.*
#
# There are several limitations to our analysis. The sample size may not fully represet the general population, and missing or zero values in pTau or AB42 could affect the accuracy of reults. Additionally, the dataset is cross-sectional, providing only a snapshot rather than capturing disease progression over time, which limits insights into how these biomakrers change during the course of Alzheimer's diesease.
#
# Future work could focus on ecpanding the dataset and including longitudinal measurments to track biomarkers dynamics. Incorporating additional biomarkers, genetic information, and more advanced statistical or machine learning models may improve diesease prediction and understanding. THroughout future research, ethical standards must remain a priority, particularly in handling pateint data and in communicating results responsibly to both rhe scientific community and public.

# %% [markdown]
# ## Unformatted Code from Early On

# %%
pip install nbconvert[webpdf]
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/35.5 MB ? eta -:--:--
#    ----------- ---------------------------- 10.0/35.5 MB 63.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 30.9/35.5 MB 83.0 MB/s eta 0:00:01
#    ---------------------------------------- 35.5/35.5 MB 67.9 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/2 [pyee]
#    ---------------------------------------- 0/2 [pyee]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
# ...

# %%
import csv
import warnings
import matplotlib.pyplot as plt

class Patient: 

    all_patients = []

    death_age = []

    education_lvl = {}

    def __init__(self, DonorID, ABeta40: float , ABeta42: float, tTau: float, pTau: float):

        self.DonorID = DonorID
        self.ABeta40 = ABeta40
        self.ABeta42 = ABeta42
        self.tTau = tTau
        self.pTau = pTau
        self.sex = None
        self.death_age = None
        self.ed_lvl = None
        self.cog_stat = None
        self.age_symp_on = None
        self.age_diag = None 
        self.head_inj = None
        self.thal_score = None
        Patient.all_patients.append(self)

    def __repr__(self):
        return f"{self.DonorID} | sex: {self.sex} | ABeta40 {self.ABeta40} | tTau {self.tTau} | pTau {self.pTau} | Death Age {self.death_age} | Thal Score {self.thal_score}"

    def get_id(self):
        return self.DonorID

    def get_ABeta42(self):
        return self.ABeta42
    
    def get_thal(self):
        return self.thal_score
    
    def get_death_age(self):
        return self.death_age
    
    @classmethod
    def combine_data(cls, filename: str):
            with open(filename, encoding="utf8") as f:
                reader = csv.DictReader(f)
                rows_of_patients = list(reader)
                #for line in csv create object
                for row in range(len(rows_of_patients)):
                    if Patient.all_patients[row].DonorID == rows_of_patients[row]["Donor ID"]:
                        if rows_of_patients[row]["Sex"] != "":
                            Patient.all_patients[row].sex = rows_of_patients[row]["Sex"]

                        if rows_of_patients[row]["Age at Death"] != "":
                            Patient.all_patients[row].death_age = int(rows_of_patients[row]["Age at Death"])

                        if rows_of_patients[row]["Highest level of education"] != "":
                            Patient.all_patients[row].ed_lvl = rows_of_patients[row]["Highest level of education"]

                        if rows_of_patients[row]["Cognitive Status"] != "":
                            Patient.all_patients[row].cog_stat = rows_of_patients[row]["Cognitive Status"]

                        if rows_of_patients[row]["Age of onset cognitive symptoms"] != "":
                            Patient.all_patients[row].age_symp_on = int(rows_of_patients[row]["Age of onset cognitive symptoms"])

                        if rows_of_patients[row]["Age of Dementia diagnosis"] != "":
                            Patient.all_patients[row].age_diag = int(rows_of_patients[row]["Age of Dementia diagnosis"])

                        if rows_of_patients[row]["Known head injury"] != "":
                            Patient.all_patients[row].head_inj = rows_of_patients[row]["Known head injury"]

                        if rows_of_patients[row]["Thal"] != "":
                            Patient.all_patients[row].thal_score = int(rows_of_patients[row]["Thal"].split()[1])
            
                    else:
                        warnings.warn("IDs do not match.")
   
    @classmethod
    def instantiate_from_csv(cls, filename: str, other_file: str):
    #open csv and create list of all rows
        with open(filename, encoding="utf8") as f:
            reader = csv.DictReader(f)
            rows_of_patients = list(reader)
            #for line in csv create object
            for row in rows_of_patients:
                Patient(
                    DonorID = row['Donor ID'],
                    ABeta40 = float(row['ABeta40 pg/ug']),
                    ABeta42 = float(row['ABeta42 pg/ug']),
                    tTau = float(row['tTAU pg/ug']),
                    pTau = float(row['pTAU pg/ug'])
                )
            Patient.all_patients.sort(key = Patient.get_id)
            Patient.combine_data(other_file)
    
    #6) MAKE A FILTER TO PULL OUT PATIENTS WITH SPECIIFC ATTRIBUTES

    @classmethod
    def filter(cls, list, ABeta40:float ="any", ABeta42:float ="any", tTau:float= "any", pTau:float ="any", sex:str ="any", death_age:int ="any", ed_lvl:str ="any", cog_stat:str ="any", age_symp_on:int ="any", age_diag:int ="any", head_inj:str ="any", thal_score:int ="any"):
        all_patients = list
        remove_list = []
        attr_list = (
                    ABeta40,
                    ABeta42,
                    tTau,
                    pTau,
                    sex,
                    death_age,
                    ed_lvl,
                    cog_stat,
                    age_symp_on,
                    age_diag,
                    head_inj,
                    thal_score
                    )
        attr_name = (
                    "ABeta40",
                    "ABeta42",
                    "tTau",
                    "pTau",
                    "sex",
                    "death_age",
                    "ed_lvl",
                    "cog_stat",
                    "age_symp_on",
                    "age_diag",
                    "head_inj",
                    "thal_score"
                    )
        for attr in range(len(attr_list)):
            if attr_list[attr] != "any":
                for patient in all_patients:
                    if getattr(patient,attr_name[attr]) != attr_list[attr]:
                        remove_list.append(patient)
                all_patients = [patient for patient in all_patients if patient not in remove_list]
                remove_list.clear()
        
        return all_patients

# %%
patient = Patient.instantiate_from_csv('UpdatedLuminex.csv', 'UpdatedMetaData.csv')

Patient.instantiate_from_csv('UpdatedLuminex.csv', 'UpdatedMetaData.csv')

for patient in Patient.all_patients:
    print(patient)
# Out:
# H19.33.004 | sex: Female | ABeta40 0.019621053 | tTau 1552.414737 | pTau 1.901052632 | Death Age 80 | Thal Score 0
# H19.33.004 | sex: None | ABeta40 0.019621053 | tTau 1552.414737 | pTau 1.901052632 | Death Age None | Thal Score None
# H20.33.001 | sex: Male | ABeta40 0.215789474 | tTau 756.0905263 | pTau 2.737894737 | Death Age 82 | Thal Score 2
# H20.33.001 | sex: None | ABeta40 0.215789474 | tTau 756.0905263 | pTau 2.737894737 | Death Age None | Thal Score None
# H20.33.002 | sex: Female | ABeta40 0.000597895 | tTau 313.5252632 | pTau 2.615789474 | Death Age 97 | Thal Score 0
# H20.33.002 | sex: None | ABeta40 0.000597895 | tTau 313.5252632 | pTau 2.615789474 | Death Age None | Thal Score None
# H20.33.004 | sex: Male | ABeta40 60.76631579 | tTau 318.5284211 | pTau 7.412631579 | Death Age 86 | Thal Score 5
# H20.33.004 | sex: None | ABeta40 60.76631579 | tTau 318.5284211 | pTau 7.412631579 | Death Age None | Thal Score None
# ...

# %%
# 4. Group by diagnosis and sort by pTau
patient_by_diagnosis = {"Alzheimers": [], "Control": []}

for patient in Patient.all_patients:
    if patient.is_AD():
        patient_by_diagnosis["Alzheimers"].append(patient)
    elif patient.is_control():
        patient_by_diagnosis["Control"].append(patient)

for group in patient_by_diagnosis:
    patient_by_diagnosis[group].sort(key=lambda p: p.pTau)

print("\nSorted Alzheimer’s Patients by pTau:")
for patient in patient_by_diagnosis["Alzheimers"]:
        print(patient)

print("\nSorted Control Patients by pTau:")
for patient in patient_by_diagnosis["Control"]:
    print(patient)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 5
#       2 patient_by_diagnosis = {"Alzheimers": [], "Control": []}
#       4 for patient in Patient.all_patients:
# ----> 5     if patient.is_AD():
#       6         patient_by_diagnosis["Alzheimers"].append(patient)
#       7     elif patient.is_control():
#
# AttributeError: 'Patient' object has no attribute 'is_AD'

# %%
#7) USE OUR FILTER TO PULL OUT AND COUNT SUB-SETS OF PATIENTS THAT ARE FILTERED

healthy = Patient.filter(Patient.all_patients, cog_stat = "No dementia")
diseased = Patient.filter(Patient.all_patients, cog_stat = "Dementia")

healthy_patients = range(len(Patient.filter(Patient.all_patients, cog_stat = "No dementia")))
healthy_pat = range (len(healthy))
diseased_patients = range(len(Patient.filter(Patient.all_patients, cog_stat = "Dementia")))

print(f'Healthy Patients = {len(healthy_patients)} | Diseased Patients = {len(diseased_patients)}')
print (f'Healthy Patients = {len(healthy)} | Diseased Patients = {len(diseased)}')
# Out:
# Healthy Patients = 42 | Diseased Patients = 42
# Healthy Patients = 42 | Diseased Patients = 42
# 168

# %%
#finding and verifying average pTau in healthy patients and creating a set of pTau values

healthypTauTotal = 0
hpTau_set = []
num = len(healthy)
n = 0
for p in healthy:
    healthypTauTotal += p.pTau
    hpTau_set.append(p.pTau)
    n +=1

avgTau = healthypTauTotal / num
print(f'Average tTau in Healthy Patients = {avgTau}')

print(healthypTauTotal)
print(n)
# Out:
# Average tTau in Healthy Patients = 3.756090225666667
# 157.75578947800003
# 42

# %%
#finding and verifying average pTau in diseased patients and creating a set of pTau values

diseasepTauTotal = 0
dpTau_set = []
num2 = len(diseased)
n2 = 0
for p in diseased:
    diseasepTauTotal += p.pTau
    dpTau_set.append(p.pTau)
    n2 +=1
avgTau2 = diseasepTauTotal / num2
print(f'Average tTau in Diseased Patients = {avgTau2}')
print(diseasepTauTotal)
# Out:
# Average tTau in Diseased Patients = 4.657543859595237
# 195.61684210299995

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats


# Calculate means and standard deviations
hmean, dmean = np.mean(hpTau_set), np.mean(dpTau_set)
stdh, stdd = np.std(hpTau_set, ddof=1), np.std(dpTau_set, ddof=1)


# Perform independent t-test
t_stat, p_val = stats.ttest_ind(hpTau_set, dpTau_set)


# Plot bar graph with error bars
labels = ['Healthy Mean pTau', 'Diseased Mean pTau']
means = [hmean, dmean]
stds = [stdh, stdd]


plt.bar(labels, means, yerr=stds, capsize=8, color=['skyblue', 'lightcoral'], alpha=0.8)
plt.ylabel('Average Value')
plt.title('Comparison of Mean pTau Levels')


# Annotate t-value on plot
plt.text(0.5, max(means) + max(stds), f"t = {t_stat:.2f}, p = {p_val:.3f}",
ha='center', fontsize=10, fontweight='bold')


plt.show()

# %%
# Extract death age and pTau for healthy and diseased patients
healthy_death_age = [p.death_age for p in healthy if p.death_age is not None]
healthy_pTau = [p.pTau for p in healthy if p.death_age is not None]

diseased_death_age = [p.death_age for p in diseased if p.death_age is not None]
diseased_pTau = [p.pTau for p in diseased if p.death_age is not None]

plt.scatter(healthy_death_age, healthy_pTau, color='skyblue', label='Healthy')
plt.scatter(diseased_death_age, diseased_pTau, color='salmon', label='Diseased')

plt.xlabel('Death Age')
plt.ylabel('pTau Amount')
plt.title('Death Age vs pTau Amount')
plt.legend()
plt.show()

# %%
# Linear regression for healthy group
slope_h, intercept_h, r_value_h, p_value_h, std_err_h = linregress(healthy_death_age, healthy_pTau)
line_h = np.array(healthy_death_age) * slope_h + intercept_h

# Linear regression for diseased group
slope_d, intercept_d, r_value_d, p_value_d, std_err_d = linregress(diseased_death_age, diseased_pTau)
line_d = np.array(diseased_death_age) * slope_d + intercept_d

plt.scatter(healthy_death_age, healthy_pTau, color='skyblue', label='Healthy')
plt.scatter(diseased_death_age, diseased_pTau, color='salmon', label='Diseased')

plt.plot(healthy_death_age, line_h, color='blue', linestyle='--', label='Healthy Regression')
plt.plot(diseased_death_age, line_d, color='red', linestyle='--', label='Diseased Regression')

plt.xlabel('Death Age')
plt.ylabel('pTau Amount')
plt.title('Death Age vs pTau Amount with Linear Regression')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Linear regression for healthy group
# ----> 2 slope_h, intercept_h, r_value_h, p_value_h, std_err_h = linregress(healthy_death_age, healthy_pTau)
#       3 line_h = np.array(healthy_death_age) * slope_h + intercept_h
#       5 # Linear regression for diseased group
#
# NameError: name 'linregress' is not defined

# %%
# Extract death age and ABeta42 for healthy and diseased patients
healthy_death_age_ABeta42 = [p.death_age for p in healthy if p.death_age is not None]
healthy_ABeta42 = [p.ABeta42 for p in healthy if p.death_age is not None]

diseased_death_age_ABeta42 = [p.death_age for p in diseased if p.death_age is not None]
diseased_ABeta42 = [p.ABeta42 for p in diseased if p.death_age is not None]

plt.scatter(healthy_death_age_ABeta42, healthy_ABeta42, color='skyblue', label='Healthy')
plt.scatter(diseased_death_age_ABeta42, diseased_ABeta42, color='salmon', label='Diseased')

plt.xlabel('Death Age')
plt.ylabel('ABeta42 Amount')
plt.title('Death Age vs ABeta42 Amount')
plt.legend()
plt.show()

# %%
from scipy.stats import linregress

# Linear regression for healthy group (ABeta42)
slope_h_abeta, intercept_h_abeta, r_value_h_abeta, p_value_h_abeta, std_err_h_abeta = linregress(healthy_death_age_ABeta42, healthy_ABeta42)
line_h_abeta = np.array(healthy_death_age_ABeta42) * slope_h_abeta + intercept_h_abeta

# Linear regression for diseased group (ABeta42)
slope_d_abeta, intercept_d_abeta, r_value_d_abeta, p_value_d_abeta, std_err_d_abeta = linregress(diseased_death_age_ABeta42, diseased_ABeta42)
line_d_abeta = np.array(diseased_death_age_ABeta42) * slope_d_abeta + intercept_d_abeta

plt.scatter(healthy_death_age_ABeta42, healthy_ABeta42, color='skyblue', label='Healthy')
plt.scatter(diseased_death_age_ABeta42, diseased_ABeta42, color='salmon', label='Diseased')

plt.plot(healthy_death_age_ABeta42, line_h_abeta, color='blue', linestyle='--', label='Healthy Regression')
plt.plot(diseased_death_age_ABeta42, line_d_abeta, color='red', linestyle='--', label='Diseased Regression')

plt.xlabel('Death Age')
plt.ylabel('ABeta42 Amount')
plt.title('Death Age vs ABeta42 Amount with Linear Regression')
plt.legend()
plt.show()

# %% [markdown]
# # Notes:
# Comparing two groups: t - test
# Comparing multiple groups - ANOVA
# Hypothesis: one sided (higher or lower) or two sided (just different)
# Data: paired or unpaired?
# unpaired: not twins/same person
# repeating measurements on the same samples
#
#
# is data normally distributed?# yes - parametric tests
# no - non parametric tests
# do different groups have equal variances? yes - standard tests
# no - welch's correction
#
# Notes 9/23/2025
# after creating scatter plot of pTau vs death age, there was no strog correlation
# between the two variables, or between ABeta42 and death age
# thinking about revising our question
# need to set up gitHub
